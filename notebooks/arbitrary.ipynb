# %%
cd ..
# Out:
# /home/pablo/Documents/code/active/sorting_algorithm
# /home/pablo/Documents/code/active/sorting_algorithm/.venv/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from onsort.discrete_prob import pnb, P, hyp, all_dist,dist
from onsort.discrete_plots import plot_p_dist, P_print
from sympy import Sum, Symbol, plot, solve, Float, Function, lambdify,floor, maximum, Piecewise
from matplotlib import pyplot as plt
import numpy as npT
from sympy.abc import i, k, m, n, x
from sympy import Lambda, Interval , Expr , Rational, Integral, S, solveset, integrate, plot, summation
from sympy.stats import Binomial, density
from functools import lru_cache

# %%
plot_p_dist(5,10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plot_p_dist(5,10)
#
# File ~/Documents/code/active/sorting_algorithm/onsort/discrete_plots.py:12, in plot_p_dist(buckets, items)
#      10 assert buckets <= items, "items cannot be less than buckets"
#      11 n1 = Symbol("n1")
# ---> 12 plot(*[hyp(buckets, items, b, n1) for b in range(buckets)], (n1, 0, items - 1))
#
# File ~/Documents/code/active/sorting_algorithm/onsort/discrete_prob.py:50, in hyp(buckets, items, bucket, n)
#      41 def hyp(buckets: int, items: int, bucket: int, n: int) -> float:
#      42     """
#      43     Probabilty of getting the correct distribution:
#      44         /= bucket
#    (...)
#      48     trials = buckets - 1
#      49     """
# ---> 50     return hyper(bucket, items - 1, n, buckets - 1)
#
# ...

# %%
from math import comb, perm, factorial

# %%
import gmpy2
from math import comb

# %%
def comb_perm(n, k):
    k = k if k < n - k else n - k
    return perm(n, k) // factorial(k)

# %%
# %timeit comb_perm(19,7)
# Out:
# 132 ns ± 22.6 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %timeit gmpy2.comb(19,7)
# Out:
# 58.4 ns ± 2.93 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %timeit comb(19,7)
# Out:
# 41.7 ns ± 6.54 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
from sympy.stats import Hypergeometric, density
from scipy.stats import hypergeom

# %%
# %timeit density(Hypergeometric("H", 10, 5, 3))(2)
# Out:
# 66.7 µs ± 3.59 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
density(Hypergeometric("H", 10, 5, 3))(2)
# Out:
# 5/12

# %%
hyper(2,10,5,3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 hyper(2,10,5,3)
#
# NameError: name 'hyper' is not defined

# %%
# %timeit hypergeom(10,5,3).pmf(2)
# Out:
# 398 µs ± 31.3 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %timeit hypergeom.pmf(2, 10,5,3)
# Out:
# 85.8 µs ± 9.63 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
hypergeom.pmf(2, 10,5,3)
# Out:
# 0.4166666666666667

# %%
hypergeom(10,5,3).pmf(2)
# Out:
# 0.4166666666666667

# %%
# %timeit hyper(2,10,5,3)
# Out:
# 148 ns ± 15.6 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
from math import comb

def hyper(k,M,n,N):
    return comb(n, k) * comb(M-n, N-k) / comb(M, N)

# %%
from onsort.discrete_prob import pnb, P, hyp, all_dist,dist

# %%
p10 = P(11,1000)
# Out:
# P(10, 1000)
# P(9, 999)
# P(8, 998)
# P(7, 997)
# P(6, 996)
# P(5, 995)
# P(4, 994)
# P(4, 993)
# P(4, 992)
# P(4, 991)
# P(4, 990)
# P(4, 989)
# P(4, 988)
# P(4, 987)
# P(4, 986)
# P(4, 985)
# P(4, 984)
# P(4, 983)
# P(4, 982)
# P(4, 981)
# P(4, 980)
# P(4, 979)
# P(4, 978)
# P(4, 977)
# P(4, 976)
# P(4, 975)
# P(4, 974)
# P(4, 973)
# P(4, 972)
# P(4, 971)
# P(4, 970)
# P(4, 969)
# P(4, 968)
# P(4, 967)
# P(4, 966)
# P(4, 965)
# P(4, 964)
# P(4, 963)
# P(4, 962)
# P(4, 961)
# P(4, 960)
# P(4, 959)
# P(4, 958)
# P(4, 957)
# P(4, 956)
# P(4, 955)
# P(4, 954)
# P(4, 953)
# P(4, 952)
# P(4, 951)
# P(4, 950)
# P(4, 949)
# P(4, 948)
# P(4, 947)
# P(4, 946)
# P(4, 945)
# P(4, 944)
# P(4, 943)
# P(4, 942)
# P(4, 941)
# P(4, 940)
# P(4, 939)
# P(4, 938)
# P(4, 937)
# P(4, 936)
# P(4, 935)
# P(4, 934)
# P(4, 933)
# P(4, 932)
# P(4, 931)
# P(4, 930)
# P(4, 929)
# P(4, 928)
# P(4, 927)
# P(4, 926)
# P(4, 925)
# P(4, 924)
# P(4, 923)
# P(4, 922)
# P(4, 921)
# P(4, 920)
# P(4, 919)
# P(4, 918)
# ...

# %%
p15 = P(15,1000)
# Out:
# P(15, 1000)
# P(14, 999)
# P(13, 998)
# P(12, 997)
# P(11, 996)
# P(11, 995)
# P(11, 994)
# P(11, 993)
# P(11, 992)
# P(11, 991)
# P(11, 990)
# P(11, 989)
# P(11, 988)
# P(11, 987)
# P(11, 986)
# P(11, 985)
# P(11, 984)
# P(11, 983)
# P(11, 982)
# P(11, 981)
# P(11, 980)
# P(11, 979)
# P(11, 978)
# P(11, 977)
# P(11, 976)

# %%
p10
# Out:
# 0.020709690216783695

# %%
float(p4)
# Out:
# 0.34426587822629257

# %%
p5 = P(5,1000)
# Out:
# P(5, 1000)
# P(4, 999)
# P(4, 998)
# P(4, 997)
# P(4, 996)
# P(4, 995)
# P(4, 994)
# P(4, 993)
# P(4, 992)
# P(4, 991)
# P(4, 990)
# P(4, 989)
# P(4, 988)
# P(4, 987)
# P(4, 986)
# P(4, 985)
# P(4, 984)
# P(4, 983)
# P(4, 982)
# P(4, 981)
# P(4, 980)
# P(4, 979)
# P(4, 978)
# P(4, 977)
# P(4, 976)
# P(4, 975)
# P(4, 974)
# P(4, 973)
# P(4, 972)
# P(4, 971)
# P(4, 970)
# P(4, 969)
# P(4, 968)
# P(4, 967)
# P(4, 966)
# P(4, 965)
# P(4, 964)
# P(4, 963)
# P(4, 962)
# P(4, 961)
# P(4, 960)
# P(4, 959)
# P(4, 958)
# P(4, 957)
# P(4, 956)
# P(4, 955)
# P(4, 954)
# P(4, 953)
# P(4, 952)
# P(4, 951)
# P(4, 950)
# P(4, 949)
# P(4, 948)
# P(4, 947)
# P(4, 946)
# P(4, 945)
# P(4, 944)
# P(4, 943)
# P(4, 942)
# P(4, 941)
# P(4, 940)
# P(4, 939)
# P(4, 938)
# P(4, 937)
# P(4, 936)
# P(4, 935)
# P(4, 934)
# P(4, 933)
# P(4, 932)
# P(4, 931)
# P(4, 930)
# P(4, 929)
# P(4, 928)
# P(4, 927)
# P(4, 926)
# P(4, 925)
# P(4, 924)
# P(4, 923)
# P(4, 922)
# P(4, 921)
# P(4, 920)
# P(4, 919)
# P(4, 918)
# ...

# %%
buckets = 5
items = 8
b = 2
n = 3

pnb(buckets,items,b,n)
pnb(buckets,items,buckets-b-1,items-n-1)
# Out:
# P(2, 4)
# P(0, 3)
# 5/14

# %%
# Out:
# 5/14

# %%
n1 = Symbol("n1", positive=True)

# %%
dist = Function("Dist")

# %%
dist(n1)
# Out:
# Dist(n1)

# %%
2*Integral(n1, (n1,0,0.5)) + 2*Integral(1-n1, (n1,0.5,1))
# Out:
# 2*Integral(n1, (n1, 0, 0.5)) + 2*Integral(1 - n1, (n1, 0.5, 1))

# %%
# [n1][_] -> 0 if n2 < n1 -> 0 with p=(1-n1)
#                         -> 2 with p=(n1)

# %%
p = Function("P")
s = Symbol("s", integer= True, positive= True)

# %%
Sum(Integral(p(n1, s), (n1, 0,1)), (s,1,2))
# Out:
# Sum(Integral(P(n1, s), (n1, 0, 1)), (s, 1, 2))

# %%
# arbitrary function, now let's say is total distance to correct solution.

# %%
# [_][X]

# %%
# threshold is 0.5

# n*(1)+()

# %%
# 

# [_][_][X][_][_][_]
